# %%
import sys

# Add path for python to look into for modules installed using pip

sys.path.append('/usr/local/lib/python3.7/site-packages/')

import quandl
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import requests
import json
import datetime
import random

np.set_printoptions(threshold=sys.maxsize)

quandl.ApiConfig.api_key = "n2tNssPxEFC9-Ad79fo-" # keep this private

figsize = (15, 8)

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Get ticker/RIC codes from different stock exchanges

# %%
def Get_Codes(stock_exchange):
    
    data = pd.read_csv(str(stock_exchange)+".csv", encoding='unicode_escape')
    company_name = []

    for i in data["Symbol"]:
    
        company_name.append(i)

    codes = np.asarray(company_name)
    
    return codes


Get_Codes("NYSE")

Get_Codes("NASDAQ")

Get_Codes("ASE")

# We must add the codes at the end to make it compatible with Refinitiv data

def Add_Extension(codes, ext):
    
    newcodes = []
    
    for i in codes:
        
        newcodes.append(str(i) + str(ext))
        
    new = np.asarray(newcodes)
    
    return new   

Add_Extension(Get_Codes("NASDAQ"), ext=".O")

# We can now create a list of extensions to call the above function for each stock exchange:

# list can be found at: 
# http://training.thomsonreuters.com/portal/docs/pdf/raymondjames/Thomson_One_Exchange_List.pdf

# For the time being we have the 3 largest American Stock Exchanges:

# - NYSE: .N
# - NASDAQ: .O
# - ASE: .A

# Get Quandl data

NYSE_quandl = list(Get_Codes("NYSE"))
NASDAQ_quandl = list(Get_Codes("NASDAQ"))
ASE_quandl = list(Get_Codes("ASE"))

# Get Rifinitiv data

NYSE_rifinitiv = list(Add_Extension(Get_Codes("NYSE"), ext=".N"))
NASDAQ_rifinitiv = list(Add_Extension(Get_Codes("NASDAQ"), ext=".O"))
ASE_rifinitiv = list(Add_Extension(Get_Codes("ASE"), ext=".A"))

print('NYSE_quandl:', len(NYSE_quandl))
print('NASDAQ_quandl:', len(NASDAQ_quandl))
print('ASE_quandl:', len(ASE_quandl))

print('NYSE_rifinitiv:', len(NYSE_rifinitiv))
print('NASDAQ_rifinitiv:', len(NASDAQ_rifinitiv))
print('ASE_rifinitiv:', len(ASE_rifinitiv))
# Out:
# NYSE_quandl: 3135
# NASDAQ_quandl: 3504
# ASE_quandl: 2266
# NYSE_rifinitiv: 3135
# NASDAQ_rifinitiv: 3504
# ASE_rifinitiv: 2266

# %% [markdown]
# ## Set time period

# %%
# Start/end dates

start = '2010-10-15'
end = '2018-10-15'

oos_start = end
oos_end = '2019-10-15'

# %% [markdown]
# ## Rifinitiv

# %%
##### Rifinitiv #####

# The following values are populated for you by Data Science Accelerator. 
# They represent your demo-level access to the data.
# Please don't share this with anyone

# RESOURCE_ENDPOINT = 'https://dsa-stg-edp-api.fr-nonprod.aws.thomsonreuters.com/data/environmental-social-governance/v1/views/scores-full'
access_token = 'uGR7cxvvqJ4mgWwva5pPN184iGGigBhY8g4ThFu0' # personal key for Data Science Accelerator access to ESG

def get_data_request(url, requestData):
    '''HTTP GET request'''
    dResp = requests.get(url, headers = {'X-api-key': access_token}, params = requestData);       

    if dResp.status_code != 200:
        raise ValueError("Unable to get data. Code %s, Message: %s" % (dResp.status_code, dResp.text));
    else:
        print("Data access successful")
        jResp = json.loads(dResp.text);
        return jResp

def get_data(ric):
    '''Gets ESG scores for a specific RIC (company) code'''
    
    requestData = {
    "universe": ric
    };

    jResp = get_data_request(RESOURCE_ENDPOINT, requestData)

    data = jResp["data"]
    headers = jResp["headers"]    

    names = [headers[x]['title'] for x in range(len(headers))]

    df = pd.DataFrame(data, columns=names )
    
    return df

# Updating the API endpoint 

RESOURCE_ENDPOINT = 'https://dsa-stg-edp-api.fr-nonprod.aws.thomsonreuters.com/data/environmental-social-governance/v1/views/measures-full'

# %% [markdown]
# ## Aggregate function

# %%
# Read available Quandl ticker symbols

tickers = pd.read_csv('ticker_list.csv', sep=',')

# %%
# Define essential loop function

def aggregate(asset1, asset2, start_date=start, end_date=end):
    
    # Quandl
    
    if 'EOD/'+asset1.replace('.', '_') in list(tickers['Quandl_Code']):
        
        try:
            quandl_data = quandl.get('EOD/'+asset1.replace('.', '_'), start_date=start_date, end_date=end_date)
        except:
            print('No Quandl data available')
            return 0
        
        # Get stocks with at least 300 Quandl entries
        
        if len(quandl_data) >= 500:
            quandl_data['Date'] = pd.to_datetime(quandl_data.index, format='%Y-%m-%d')
            quandl_data['Year'] = quandl_data['Date'].dt.year
            quandl_yearly = quandl_data.groupby(['Year']).mean()
        else:
            return 0
    else:
        return 0
    
    # Refinitiv
    
    try:
        refinitiv_data = get_data(asset2)
    except:
        return 0
        
    if len(refinitiv_data) != 0:
        refinitiv_data['Date'] = pd.to_datetime(refinitiv_data['Period End Date'], format='%Y-%m-%d')
        refinitiv_data['Year'] = refinitiv_data['Date'].dt.year
        refinitiv_data['Period End Date'] = pd.to_datetime(refinitiv_data['Period End Date'], format='%Y-%m-%d')
        refinitiv_data = refinitiv_data[(refinitiv_data['Period End Date'] >= start) & 
                                        (refinitiv_data['Period End Date'] <= end)]
        refinitiv_data.set_index('Year', inplace=True)
        refinitiv_data.dropna(subset=['TRESG Combined Score'], inplace=True)
    else:
        return 0
        
    # Join datasets (if both available)
    
    all_data = quandl_yearly.join(refinitiv_data, on='Year', how='left')
    
    return all_data
    
#     if isinstance(quandl_yearly, pd.DataFrame) and refinitiv_data == 0:
#         print('DATA NOT AVAILABLE FOR:', asset1, ',', asset2)
#         return 0
#     elif quandl_yearly == 0 and isinstance(refinitiv_data, pd.DataFrame):
#         print('DATA NOT AVAILABLE FOR:', asset1, ',', asset2)
#         return 0
#     elif quandl_yearly == 0 and refinitiv_data == 0:
#         print('DATA NOT AVAILABLE FOR:', asset1, ',', asset2)
#         return 0
#     elif isinstance(quandl_yearly, pd.DataFrame) and isinstance(refinitiv_data, pd.DataFrame):
#         all_data = quandl_yearly.join(refinitiv_data, on='Year', how='left')
#         return all_data
#     else:
#         all_data = quandl_yearly.join(refinitiv_data, on='Year', how='left')
#         return all_data

# %% [markdown]
# ## Quandl-Rifinitive loop

# %%
n = 500

index = random.sample(population=range(0, len(NASDAQ_quandl)), k=n)

assets_quandl = [NASDAQ_quandl[i] for i in index]

assets_ref = [NASDAQ_rifinitiv[i] for i in index]

datasets = []

i = 1

for asset1, asset2 in zip(assets_quandl,assets_ref):
    
    print(i, '/', n, ':', asset1, ',', asset2)
    
    data_tmp = aggregate(asset1, asset2)
    
    i += 1
    
    if isinstance(data_tmp, pd.DataFrame):
        datasets.append(data_tmp)
        print(data_tmp.shape, '\n')
    else:
        continue

print('Done')
# Out:
# 1 / 500 : SFLY , SFLY.O
# Data access successful
# (9, 267)
#
# 2 / 500 : NWSA , NWSA.O
# Data access successful
# (6, 282)
#
# 3 / 500 : BBI , BBI.O
# 4 / 500 : SHV , SHV.O
# Data access successful
# 5 / 500 : WTREP , WTREP.O
# 6 / 500 : JFU , JFU.O
# 7 / 500 : DGICA , DGICA.O
# Data access successful
# (9, 265)
#
# 8 / 500 : UBIO , UBIO.O
# Data access successful
# 9 / 500 : ARVN , ARVN.O
# 10 / 500 : BAND , BAND.O
# 11 / 500 : FGEN , FGEN.O
# Data access successful
# (5, 267)
#
# 12 / 500 : ZBRA , ZBRA.O
# Data access successful
# (9, 279)
#
# 13 / 500 : MRBK , MRBK.O
# 14 / 500 : DWCR , DWCR.O
# 15 / 500 : CRNT , CRNT.O
# Data access successful
# 16 / 500 : MRLN , MRLN.O
# Data access successful
# (9, 269)
#
# 17 / 500 : DRAD , DRAD.O
# Data access successful
# 18 / 500 : SNPS , SNPS.O
# Data access successful
# (9, 280)
#
# 19 / 500 : CATC , CATC.O
# 20 / 500 : RETO , RETO.O
# 21 / 500 : ISHG , ISHG.O
# Data access successful
# 22 / 500 : ORRF , ORRF.O
# Data access successful
# 23 / 500 : IHRT , IHRT.O
# 24 / 500 : SYNC , SYNC.O
# Data access successful
# 25 / 500 : CWBC , CWBC.O
# Data access successful
# 26 / 500 : GOODN , GOODN.O
# Data access successful
# (5, 265)
#
# 27 / 500 : CASI , CASI.O
# Data access successful
# (9, 262)
#
# 28 / 500 : SENEB , SENEB.O
# Data access successful
# 29 / 500 : ACIW , ACIW.O
# Data access successful
# (9, 266)
#
# 30 / 500 : PEGI , PEGI.O
# Data access successful
# (6, 285)
#
# 31 / 500 : AQB , AQB.O
# 32 / 500 : TCBK , TCBK.O
# Data access successful
# (9, 271)
#
# 33 / 500 : FNK , FNK.O
# Data access successful
# 34 / 500 : PAYS , PAYS.O
# 35 / 500 : CDEV , CDEV.O
# Data access successful
# (3, 278)
#
# 36 / 500 : MTLS , MTLS.O
# Data access successful
# 37 / 500 : SNGX , SNGX.O
# 38 / 500 : HARP , HARP.O
# 39 / 500 : REPH , REPH.O
# Data access successful
# 40 / 500 : GAINM , GAINM.O
# Data access successful
# 41 / 500 : EVOK , EVOK.O
# Data access successful
# 42 / 500 : BOMN , BOMN.O
# 43 / 500 : AGFS , AGFS.O
# Data access successful
# 44 / 500 : JNCE , JNCE.O
# 45 / 500 : IUSS , IUSS.O
# 46 / 500 : CATY , CATY.O
# Data access successful
# (9, 272)
#
# 47 / 500 : TRCH , TRCH.O
# Data access successful
# 48 / 500 : UBFO , UBFO.O
# Data access successful
# 49 / 500 : ERYP , ERYP.O
# 50 / 500 : CIBR , CIBR.O
# Data access successful
# 51 / 500 : LKFN , LKFN.O
# Data access successful
# (9, 270)
#
# 52 / 500 : GRID , GRID.O
# Data access successful
# 53 / 500 : AMBCW , AMBCW.O
# Data access successful
# (6, 275)
#
# 54 / 500 : DYNT , DYNT.O
# Data access successful
# 55 / 500 : FKU , FKU.O
# Data access successful
# 56 / 500 : VTWV , VTWV.O
# Data access successful
# 57 / 500 : JCOM , JCOM.O
# Data access successful
# (9, 269)
#
# 58 / 500 : QADB , QADB.O
# Data access successful
# (9, 264)
#
# 59 / 500 : WRTC , WRTC.O
# 60 / 500 : FULC , FULC.O
# 61 / 500 : QLYS , QLYS.O
# Data access successful
# (7, 267)
#
# 62 / 500 : STAF , STAF.O
# Data access successful
# 63 / 500 : BOKFL , BOKFL.O
# Data access successful
# (3, 270)
#
# 64 / 500 : AGTC , AGTC.O
# Data access successful
# 65 / 500 : ACIU , ACIU.O
# Data access successful
# 66 / 500 : TOTAW , TOTAW.O
# 67 / 500 : DVLU , DVLU.O
# 68 / 500 : CIVB , CIVB.O
# Data access successful
# 69 / 500 : FMCIU , FMCIU.O
# 70 / 500 : BRKR , BRKR.O
# Data access successful
# (9, 276)
#
# 71 / 500 : TBLTW , TBLTW.O
# 72 / 500 : RMTI , RMTI.O
# Data access successful
# (9, 271)
#
# 73 / 500 : BGNE , BGNE.O
# Data access successful
# 74 / 500 : USLM , USLM.O
# Data access successful
# (9, 265)
#
# 75 / 500 : SEAC , SEAC.O
# Data access successful
# 76 / 500 : NDRAW , NDRAW.O
# 77 / 500 : CSF , CSF.O
# Data access successful
# 78 / 500 : FWRD , FWRD.O
# Data access successful
# (9, 268)
#
# 79 / 500 : SONGW , SONGW.O
# 80 / 500 : ADAP , ADAP.O
# Data access successful
# 81 / 500 : BBCP , BBCP.O
# 82 / 500 : CART , CART.O
# Data access successful
# 83 / 500 : ARNA , ARNA.O
# Data access successful
# (9, 269)
#
# 84 / 500 : FTA , FTA.O
# Data access successful
# 85 / 500 : BGFV , BGFV.O
# Data access successful
# 86 / 500 : BSQR , BSQR.O
# Data access successful
# 87 / 500 : PVAL , PVAL.O
# 88 / 500 : TWMC , TWMC.O
# Data access successful
# 89 / 500 : CLGN , CLGN.O
# 90 / 500 : LMNR , LMNR.O
# Data access successful
# (9, 268)
#
# 91 / 500 : MAT , MAT.O
# Data access successful
# (9, 328)
#
# 92 / 500 : AMKR , AMKR.O
# Data access successful
# (9, 267)
#
# 93 / 500 : UGLD , UGLD.O
# Data access successful
# 94 / 500 : IMTE , IMTE.O
# 95 / 500 : NVEE , NVEE.O
# Data access successful
# (6, 265)
#
# 96 / 500 : GO , GO.O
# 97 / 500 : LDSF , LDSF.O
# 98 / 500 : SIBN , SIBN.O
# 99 / 500 : PIRS , PIRS.O
# Data access successful
# 100 / 500 : TPCO , TPCO.O
# Data access successful
# (5, 273)
#
# 101 / 500 : ZS , ZS.O
# 102 / 500 : RFDI , RFDI.O
# Data access successful
# 103 / 500 : WISA , WISA.O
# 104 / 500 : SKYW , SKYW.O
# Data access successful
# (9, 268)
#
# 105 / 500 : SNHNL , SNHNL.O
# Data access successful
# (3, 272)
#
# 106 / 500 : USLB , USLB.O
# Data access successful
# 107 / 500 : WIFI , WIFI.O
# Data access successful
# (8, 267)
#
# 108 / 500 : RVLT , RVLT.O
# Data access successful
# 109 / 500 : NOVT , NOVT.O
# Data access successful
# (3, 265)
#
# 110 / 500 : RUBY , RUBY.O
# 111 / 500 : CYCCP , CYCCP.O
# Data access successful
# 112 / 500 : NDRA , NDRA.O
# 113 / 500 : TZACU , TZACU.O
# 114 / 500 : SLNO , SLNO.O
# 115 / 500 : SAUC , SAUC.O
# Data access successful
# 116 / 500 : TKKSR , TKKSR.O
# 117 / 500 : HCACW , HCACW.O
# 118 / 500 : LSXMK , LSXMK.O
# Data access successful
# (3, 268)
#
# 119 / 500 : FCFS , FCFS.O
# Data access successful
# (9, 269)
#
# 120 / 500 : MTP , MTP.O
# Data access successful
# 121 / 500 : PPSI , PPSI.O
# Data access successful
# 122 / 500 : INOD , INOD.O
# Data access successful
# 123 / 500 : TW , TW.O
# 124 / 500 : CLRO , CLRO.O
# Data access successful
# 125 / 500 : VRIG , VRIG.O
# Data access successful
# 126 / 500 : JAGX , JAGX.O
# Data access successful
# 127 / 500 : FCAN , FCAN.O
# Data access successful
# 128 / 500 : SRCE , SRCE.O
# Data access successful
# (9, 266)
#
# 129 / 500 : NXGN , NXGN.O
# 130 / 500 : PRIM , PRIM.O
# Data access successful
# (9, 280)
#
# 131 / 500 : PSL , PSL.O
# Data access successful
# 132 / 500 : FLL , FLL.O
# Data access successful
# 133 / 500 : ASRVP , ASRVP.O
# Data access successful
# 134 / 500 : NMRK , NMRK.O
# 135 / 500 : OSTK , OSTK.O
# Data access successful
# (9, 273)
#
# 136 / 500 : CELGZ , CELGZ.O
# Data access successful
# (9, 337)
#
# 137 / 500 : SIRI , SIRI.O
# Data access successful
# (9, 289)
#
# 138 / 500 : AEGN , AEGN.O
# Data access successful
# (9, 268)
#
# 139 / 500 : CFB , CFB.O
# 140 / 500 : FCBP , FCBP.O
# 141 / 500 : SRPT , SRPT.O
# Data access successful
# (9, 272)
#
# 142 / 500 : MNTX , MNTX.O
# Data access successful
# 143 / 500 : QADA , QADA.O
# Data access successful
# (9, 264)
#
# 144 / 500 : SBUX , SBUX.O
# Data access successful
# (9, 332)
#
# 145 / 500 : PY , PY.O
# Data access successful
# 146 / 500 : ERI , ERI.O
# Data access successful
# (5, 270)
#
# 147 / 500 : MGRC , MGRC.O
# Data access successful
# (9, 263)
#
# 148 / 500 : EVOP , EVOP.O
# 149 / 500 : BNGOW , BNGOW.O
# 150 / 500 : PECK , PECK.O
# Data access successful
# 151 / 500 : PRAA , PRAA.O
# Data access successful
# (9, 268)
#
# 152 / 500 : ODFL , ODFL.O
# Data access successful
# (9, 269)
#
# 153 / 500 : SAVA , SAVA.O
# Data access successful
# 154 / 500 : TRMT , TRMT.O
# 155 / 500 : DPHC , DPHC.O
# 156 / 500 : CRMT , CRMT.O
# Data access successful
# (9, 265)
#
# 157 / 500 : CHSCN , CHSCN.O
# Data access successful
# 158 / 500 : FTCS , FTCS.O
# Data access successful
# 159 / 500 : TSG , TSG.O
# Data access successful
# (9, 273)
#
# 160 / 500 : GAIA , GAIA.O
# Data access successful
# 161 / 500 : NESR , NESR.O
# 162 / 500 : IIIN , IIIN.O
# 163 / 500 : MTSI , MTSI.O
# Data access successful
# (7, 269)
#
# 164 / 500 : PTMN , PTMN.O
# Data access successful
# 165 / 500 : VLGEA , VLGEA.O
# Data access successful
# (9, 261)
#
# 166 / 500 : MLND , MLND.O
# Data access successful
# 167 / 500 : CELC , CELC.O
# 168 / 500 : RNST , RNST.O
# Data access successful
# (9, 267)
#
# 169 / 500 : SPSC , SPSC.O
# Data access successful
# (9, 268)
#
# 170 / 500 : CHSCO , CHSCO.O
# Data access successful
# 171 / 500 : INDB , INDB.O
# Data access successful
# (9, 271)
#
# 172 / 500 : CZWI , CZWI.O
# Data access successful
# 173 / 500 : GRFS , GRFS.O
# Data access successful
# (8, 335)
#
# 174 / 500 : NTES , NTES.O
# Data access successful
# (9, 256)
#
# 175 / 500 : WTFC , WTFC.O
# Data access successful
# (9, 268)
#
# 176 / 500 : VERU , VERU.O
# Data access successful
# 177 / 500 : HHHHU , HHHHU.O
# 178 / 500 : CVET , CVET.O
# 179 / 500 : SFBC , SFBC.O
# Data access successful
# 180 / 500 : CPRX , CPRX.O
# Data access successful
# (9, 252)
#
# 181 / 500 : GIFI , GIFI.O
# Data access successful
# 182 / 500 : OSS , OSS.O
# 183 / 500 : ESGD , ESGD.O
# Data access successful
# 184 / 500 : CVCO , CVCO.O
# Data access successful
# (9, 268)
#
# 185 / 500 : NYMT , NYMT.O
# Data access successful
# (9, 267)
#
# 186 / 500 : WASH , WASH.O
# Data access successful
# (9, 269)
#
# 187 / 500 : MAYS , MAYS.O
# Data access successful
# 188 / 500 : OXSQ , OXSQ.O
# Data access successful
# 189 / 500 : HAIR , HAIR.O
# 190 / 500 : LUNA , LUNA.O
# Data access successful
# 191 / 500 : FORD , FORD.O
# Data access successful
# 192 / 500 : CPAH , CPAH.O
# Data access successful
# 193 / 500 : SBFG , SBFG.O
# Data access successful
# 194 / 500 : EBAYL , EBAYL.O
# Data access successful
# (3, 314)
#
# 195 / 500 : CYCN , CYCN.O
# 196 / 500 : AMEH , AMEH.O
# 197 / 500 : MNOV , MNOV.O
# Data access successful
# (9, 268)
#
# 198 / 500 : ALRN , ALRN.O
# 199 / 500 : EA , EA.O
# Data access successful
# (9, 286)
#
# 200 / 500 : VTIQU , VTIQU.O
# 201 / 500 : QABA , QABA.O
# Data access successful
# 202 / 500 : KBLM , KBLM.O
# 203 / 500 : FTNT , FTNT.O
# Data access successful
# (9, 270)
#
# 204 / 500 : CPLP , CPLP.O
# Data access successful
# 205 / 500 : DFFN , DFFN.O
# 206 / 500 : NWBI , NWBI.O
# Data access successful
# (9, 269)
#
# 207 / 500 : BBSI , BBSI.O
# Data access successful
# (9, 269)
#
# 208 / 500 : TAST , TAST.O
# Data access successful
# (10, 269)
#
# 209 / 500 : SCYX , SCYX.O
# Data access successful
# 210 / 500 : GOODP , GOODP.O
# Data access successful
# (9, 265)
#
# 211 / 500 : MARPS , MARPS.O
# Data access successful
# 212 / 500 : HNNA , HNNA.O
# Data access successful
# 213 / 500 : AMTB , AMTB.O
# 214 / 500 : TWOU , TWOU.O
# Data access successful
# (5, 269)
#
# 215 / 500 : GOGO , GOGO.O
# Data access successful
# (6, 268)
#
# 216 / 500 : ITRN , ITRN.O
# Data access successful
# 217 / 500 : TCF , TCF.O
# Data access successful
# (9, 267)
#
# 218 / 500 : MGI , MGI.O
# Data access successful
# (9, 273)
#
# 219 / 500 : GLPG , GLPG.O
# Data access successful
# (4, 259)
#
# 220 / 500 : NTCT , NTCT.O
# Data access successful
# (9, 268)
#
# 221 / 500 : ITRM , ITRM.O
# 222 / 500 : CHSCM , CHSCM.O
# Data access successful
# 223 / 500 : CWST , CWST.O
# Data access successful
# (9, 295)
#
# 224 / 500 : STKL , STKL.O
# Data access successful
# 225 / 500 : CIFS , CIFS.O
# 226 / 500 : ABIL , ABIL.O
# Data access successful
# 227 / 500 : SXTC , SXTC.O
# 228 / 500 : OFSSL , OFSSL.O
# 229 / 500 : HOLI , HOLI.O
# Data access successful
# 230 / 500 : TCMD , TCMD.O
# Data access successful
# (3, 268)
#
# 231 / 500 : CYRX , CYRX.O
# Data access successful
# (4, 264)
#
# 232 / 500 : PCAR , PCAR.O
# Data access successful
# (9, 306)
#
# 233 / 500 : OFSSZ , OFSSZ.O
# 234 / 500 : LPTX , LPTX.O
# 235 / 500 : JAKK , JAKK.O
# Data access successful
# 236 / 500 : APLT , APLT.O
# 237 / 500 : FCSC , FCSC.O
# Data access successful
# 238 / 500 : MPWR , MPWR.O
# Data access successful
# (9, 269)
#
# 239 / 500 : HSDT , HSDT.O
# 240 / 500 : CSII , CSII.O
# Data access successful
# (9, 269)
#
# 241 / 500 : ASRT , ASRT.O
# Data access successful
# (9, 275)
#
# 242 / 500 : SLP , SLP.O
# Data access successful
# 243 / 500 : AXLA , AXLA.O
# 244 / 500 : DSGX , DSGX.O
# Data access successful
# (9, 262)
#
# 245 / 500 : RTTR , RTTR.O
# Data access successful
# 246 / 500 : HUBG , HUBG.O
# Data access successful
# (9, 268)
#
# 247 / 500 : SPPI , SPPI.O
# Data access successful
# (9, 267)
#
# 248 / 500 : ISCA , ISCA.O
# Data access successful
# (9, 272)
#
# 249 / 500 : TKKSW , TKKSW.O
# 250 / 500 : WHF , WHF.O
# Data access successful
# 251 / 500 : TDIV , TDIV.O
# Data access successful
# 252 / 500 : CODX , CODX.O
# 253 / 500 : GALT , GALT.O
# Data access successful
# 254 / 500 : ZYXI , ZYXI.O
# 255 / 500 : OBLN , OBLN.O
# Data access successful
# 256 / 500 : XFOR , XFOR.O
# 257 / 500 : FMHI , FMHI.O
# 258 / 500 : MRNS , MRNS.O
# Data access successful
# 259 / 500 : TREE , TREE.O
# Data access successful
# (9, 269)
#
# 260 / 500 : AAXJ , AAXJ.O
# Data access successful
# 261 / 500 : DJCO , DJCO.O
# Data access successful
# 262 / 500 : DNJR , DNJR.O
# 263 / 500 : MVBF , MVBF.O
# 264 / 500 : MNLO , MNLO.O
# 265 / 500 : CDNA , CDNA.O
# Data access successful
# (5, 267)
#
# 266 / 500 : HAIN , HAIN.O
# Data access successful
# (9, 274)
#
# 267 / 500 : LMST , LMST.O
# 268 / 500 : CFBK , CFBK.O
# Data access successful
# 269 / 500 : FDT , FDT.O
# Data access successful
# 270 / 500 : KINS , KINS.O
# Data access successful
# 271 / 500 : PACB , PACB.O
# Data access successful
# (9, 269)
#
# 272 / 500 : TROV , TROV.O
# Data access successful
# 273 / 500 : FARM , FARM.O
# Data access successful
# (9, 310)
#
# 274 / 500 : JD , JD.O
# Data access successful
# (5, 258)
#
# 275 / 500 : MFSF , MFSF.O
# Data access successful
# 276 / 500 : RNET , RNET.O
# Data access successful
# 277 / 500 : FCCO , FCCO.O
# Data access successful
# 278 / 500 : EARS , EARS.O
# Data access successful
# 279 / 500 : MITO , MITO.O
# 280 / 500 : NGM , NGM.O
# 281 / 500 : ELOX , ELOX.O
# 282 / 500 : PRGX , PRGX.O
# Data access successful
# 283 / 500 : ASYS , ASYS.O
# Data access successful
# 284 / 500 : NXST , NXST.O
# Data access successful
# (9, 271)
#
# 285 / 500 : NTRA , NTRA.O
# Data access successful
# (4, 270)
#
# 286 / 500 : OSMT , OSMT.O
# 287 / 500 : PLAY , PLAY.O
# Data access successful
# (5, 270)
#
# 288 / 500 : ROBT , ROBT.O
# 289 / 500 : BDGE , BDGE.O
# Data access successful
# (9, 266)
#
# 290 / 500 : LIQT , LIQT.O
# Data access successful
# 291 / 500 : AUTO , AUTO.O
# Data access successful
# 292 / 500 : CLRB , CLRB.O
# Data access successful
# 293 / 500 : CYAN , CYAN.O
# Data access successful
# 294 / 500 : HAS , HAS.O
# Data access successful
# (9, 342)
#
# 295 / 500 : VBFC , VBFC.O
# Data access successful
# 296 / 500 : CCB , CCB.O
# 297 / 500 : PDFS , PDFS.O
# Data access successful
# (9, 270)
#
# 298 / 500 : FDEF , FDEF.O
# Data access successful
# (9, 267)
#
# 299 / 500 : EYEN , EYEN.O
# 300 / 500 : VCSH , VCSH.O
# Data access successful
# 301 / 500 : PBTS , PBTS.O
# 302 / 500 : CORT , CORT.O
# Data access successful
# (9, 268)
#
# 303 / 500 : CSGP , CSGP.O
# Data access successful
# (9, 269)
#
# 304 / 500 : EQ , EQ.O
# 305 / 500 : GRBK , GRBK.O
# Data access successful
# (9, 268)
#
# 306 / 500 : TZACW , TZACW.O
# 307 / 500 : ABMD , ABMD.O
# Data access successful
# (9, 270)
#
# 308 / 500 : OPHC , OPHC.O
# Data access successful
# 309 / 500 : SFIX , SFIX.O
# 310 / 500 : MU , MU.O
# Data access successful
# (9, 325)
#
# 311 / 500 : FIXD , FIXD.O
# 312 / 500 : JFKKU , JFKKU.O
# 313 / 500 : OXFD , OXFD.O
# Data access successful
# (6, 272)
#
# 314 / 500 : PRTK , PRTK.O
# Data access successful
# (9, 269)
#
# 315 / 500 : WVE , WVE.O
# Data access successful
# (4, 263)
#
# 316 / 500 : BNTX , BNTX.O
# 317 / 500 : NXTC , NXTC.O
# 318 / 500 : PID , PID.O
# Data access successful
# 319 / 500 : MKSI , MKSI.O
# Data access successful
# (9, 269)
#
# 320 / 500 : CHUY , CHUY.O
# Data access successful
# (7, 269)
#
# 321 / 500 : MCRB , MCRB.O
# Data access successful
# (4, 272)
#
# 322 / 500 : FLIC , FLIC.O
# Data access successful
# (9, 270)
#
# 323 / 500 : LEGR , LEGR.O
# 324 / 500 : CNCE , CNCE.O
# Data access successful
# (5, 267)
#
# 325 / 500 : GECCN , GECCN.O
# 326 / 500 : KE , KE.O
# Data access successful
# (5, 259)
#
# 327 / 500 : HYAC , HYAC.O
# 328 / 500 : ZIONW , ZIONW.O
# Data access successful
# (9, 279)
#
# 329 / 500 : KOOL , KOOL.O
# Data access successful
# 330 / 500 : HSACW , HSACW.O
# 331 / 500 : LRCX , LRCX.O
# Data access successful
# (9, 326)
#
# 332 / 500 : ABEO , ABEO.O
# Data access successful
# (9, 263)
#
# 333 / 500 : PDLI , PDLI.O
# Data access successful
# (9, 278)
#
# 334 / 500 : FNWB , FNWB.O
# Data access successful
# 335 / 500 : ROLL , ROLL.O
# Data access successful
# (9, 267)
#
# 336 / 500 : SY , SY.O
# 337 / 500 : ISSC , ISSC.O
# Data access successful
# 338 / 500 : PLIN , PLIN.O
# 339 / 500 : EDTX , EDTX.O
# 340 / 500 : REAL , REAL.O
# 341 / 500 : HCM , HCM.O
# Data access successful
# (3, 262)
#
# 342 / 500 : NNDM , NNDM.O
# Data access successful
# 343 / 500 : ADMP , ADMP.O
# Data access successful
# 344 / 500 : NAVI , NAVI.O
# Data access successful
# (5, 275)
#
# 345 / 500 : LAZY , LAZY.O
# 346 / 500 : CSGS , CSGS.O
# Data access successful
# (9, 267)
#
# 347 / 500 : HMHC , HMHC.O
# Data access successful
# (6, 271)
#
# 348 / 500 : BOSC , BOSC.O
# Data access successful
# 349 / 500 : LEVL , LEVL.O
# 350 / 500 : AEMD , AEMD.O
# Data access successful
# 351 / 500 : FLXS , FLXS.O
# Data access successful
# (9, 268)
#
# 352 / 500 : BATRA , BATRA.O
# Data access successful
# (3, 268)
#
# 353 / 500 : PKBK , PKBK.O
# Data access successful
# 354 / 500 : TWIN , TWIN.O
# Data access successful
# 355 / 500 : USAK , USAK.O
# Data access successful
# 356 / 500 : ON , ON.O
# Data access successful
# (9, 327)
#
# 357 / 500 : CRUS , CRUS.O
# Data access successful
# (9, 268)
#
# 358 / 500 : GLYC , GLYC.O
# Data access successful
# (5, 269)
#
# 359 / 500 : FNSR , FNSR.O
# Data access successful
# (9, 266)
#
# 360 / 500 : THCAU , THCAU.O
# 361 / 500 : AXGT , AXGT.O
# Data access successful
# (4, 269)
#
# 362 / 500 : PNRG , PNRG.O
# Data access successful
# 363 / 500 : PNTG , PNTG.O
# 364 / 500 : BPYPO , BPYPO.O
# 365 / 500 : PAAC , PAAC.O
# 366 / 500 : UHAL , UHAL.O
# Data access successful
# (9, 261)
#
# 367 / 500 : PTCT , PTCT.O
# Data access successful
# (6, 268)
#
# 368 / 500 : MREO , MREO.O
# 369 / 500 : AVAV , AVAV.O
# Data access successful
# (9, 269)
#
# 370 / 500 : CHSCL , CHSCL.O
# Data access successful
# 371 / 500 : CNTY , CNTY.O
# Data access successful
# 372 / 500 : ORBC , ORBC.O
# Data access successful
# (9, 267)
#
# 373 / 500 : FIVE , FIVE.O
# Data access successful
# (7, 270)
#
# 374 / 500 : CFBI , CFBI.O
# 375 / 500 : TGTX , TGTX.O
# 376 / 500 : NATR , NATR.O
# 377 / 500 : EPZM , EPZM.O
# 378 / 500 : ICAD , ICAD.O
# 379 / 500 : FSEA , FSEA.O
# 380 / 500 : PZZA , PZZA.O
# 381 / 500 : FANH , FANH.O
# 382 / 500 : ASTC , ASTC.O
# 383 / 500 : DOCU , DOCU.O
# 384 / 500 : WWR , WWR.O
# 385 / 500 : XOMA , XOMA.O
# 386 / 500 : TMDI , TMDI.O
# 387 / 500 : APPF , APPF.O
# 388 / 500 : PAVMZ , PAVMZ.O
# 389 / 500 : RMNI , RMNI.O
# 390 / 500 : FBIZ , FBIZ.O
# 391 / 500 : INAP , INAP.O
# 392 / 500 : GSIT , GSIT.O
# 393 / 500 : FEUZ , FEUZ.O
# 394 / 500 : ICPT , ICPT.O
# 395 / 500 : FTAG , FTAG.O
# 396 / 500 : VRSK , VRSK.O
# 397 / 500 : EDIT , EDIT.O
# 398 / 500 : CLAR , CLAR.O
# 399 / 500 : CAPR , CAPR.O
# 400 / 500 : COHU , COHU.O
# 401 / 500 : AMRH , AMRH.O
# 402 / 500 : ALGR , ALGR.O
# 403 / 500 : MICT , MICT.O
# 404 / 500 : HSACU , HSACU.O
# 405 / 500 : NVTR , NVTR.O
# 406 / 500 : ATOS , ATOS.O
# 407 / 500 : OKTA , OKTA.O
# 408 / 500 : HTGM , HTGM.O
# 409 / 500 : NURO , NURO.O
# 410 / 500 : FFIV , FFIV.O
# 411 / 500 : TSCBP , TSCBP.O
# 412 / 500 : EBAY , EBAY.O
# 413 / 500 : PSCU , PSCU.O
# 414 / 500 : ATLC , ATLC.O
# 415 / 500 : SSYS , SSYS.O
# 416 / 500 : ARCT , ARCT.O
# 417 / 500 : KLIC , KLIC.O
# 418 / 500 : SNH , SNH.O
# 419 / 500 : FRAN , FRAN.O
# 420 / 500 : ULBI , ULBI.O
# 421 / 500 : TRMD , TRMD.O
# 422 / 500 : SQLV , SQLV.O
# 423 / 500 : FEMB , FEMB.O
# 424 / 500 : FEX , FEX.O
# 425 / 500 : GOOG , GOOG.O
# 426 / 500 : TWST , TWST.O
# 427 / 500 : MLAB , MLAB.O
# 428 / 500 : PFIN , PFIN.O
# 429 / 500 : PIXY , PIXY.O
# 430 / 500 : TELL , TELL.O
# 431 / 500 : ABCB , ABCB.O
# 432 / 500 : SPNS , SPNS.O
# 433 / 500 : FHK , FHK.O
# 434 / 500 : DGRS , DGRS.O
# 435 / 500 : IMMU , IMMU.O
# 436 / 500 : EFSC , EFSC.O
# 437 / 500 : PLXP , PLXP.O
# 438 / 500 : PLYA , PLYA.O
# 439 / 500 : HNRG , HNRG.O
# 440 / 500 : PDEV , PDEV.O
# 441 / 500 : SGLB , SGLB.O
# 442 / 500 : GLNG , GLNG.O
# 443 / 500 : USEG , USEG.O
# 444 / 500 : WVFC , WVFC.O
# 445 / 500 : TYHT , TYHT.O
# 446 / 500 : ACER , ACER.O
# 447 / 500 : IGLD , IGLD.O
# 448 / 500 : NEOG , NEOG.O
# 449 / 500 : ICBK , ICBK.O
# 450 / 500 : STNLU , STNLU.O
# 451 / 500 : MYT , MYT.O
# 452 / 500 : EMCF , EMCF.O
# 453 / 500 : DMTK , DMTK.O
# 454 / 500 : UONE , UONE.O
# 455 / 500 : SOXX , SOXX.O
# 456 / 500 : PLC , PLC.O
# 457 / 500 : PUI , PUI.O
# 458 / 500 : MTSC , MTSC.O
# 459 / 500 : BECN , BECN.O
# 460 / 500 : NATI , NATI.O
# 461 / 500 : LDRI , LDRI.O
# 462 / 500 : EMIF , EMIF.O
# 463 / 500 : ATVI , ATVI.O
# 464 / 500 : COCP , COCP.O
# 465 / 500 : SLNOW , SLNOW.O
# 466 / 500 : APEX , APEX.O
# 467 / 500 : SSNT , SSNT.O
# 468 / 500 : CXDC , CXDC.O
# 469 / 500 : IBUY , IBUY.O
# 470 / 500 : LOCO , LOCO.O
# 471 / 500 : MDSO , MDSO.O
# 472 / 500 : NEPT , NEPT.O
# 473 / 500 : BLUE , BLUE.O
# 474 / 500 : INTG , INTG.O
# 475 / 500 : ALLK , ALLK.O
# 476 / 500 : BWAY , BWAY.O
# 477 / 500 : SMRT , SMRT.O
# 478 / 500 : INTU , INTU.O
# 479 / 500 : IMV , IMV.O
# 480 / 500 : SLCT , SLCT.O
# 481 / 500 : MSBF , MSBF.O
# 482 / 500 : NGHCN , NGHCN.O
# 483 / 500 : ATHE , ATHE.O
# 484 / 500 : ESGR , ESGR.O
# 485 / 500 : BCBP , BCBP.O
# 486 / 500 : IPWR , IPWR.O
# 487 / 500 : ICCH , ICCH.O
# 488 / 500 : CFA , CFA.O
# 489 / 500 : NVEC , NVEC.O
# 490 / 500 : GENY , GENY.O
# 491 / 500 : MGYR , MGYR.O
# 492 / 500 : EQRR , EQRR.O
# 493 / 500 : CVV , CVV.O
# 494 / 500 : AXGN , AXGN.O
# 495 / 500 : XELB , XELB.O
# 496 / 500 : ANTE , ANTE.O
# 497 / 500 : OXBRW , OXBRW.O
# 498 / 500 : GYRO , GYRO.O
# 499 / 500 : CTHR , CTHR.O
# 500 / 500 : MNDO , MNDO.O
# Done

# %%
# Get all column names

col_names = []

for d in datasets:
    col_names.append(d.columns)
    
# Intersection of list of lists

unique_colnames = list(set.intersection(*map(set, col_names)))

# %%
# Subset dataframes in datasets

new_data = []

for d in datasets:
    df_tmp = d[np.intersect1d(d.columns, unique_colnames)]
    df_tmp = df_tmp.loc[:, ~df_tmp.columns.duplicated()]
    new_data.append(df_tmp)
    
# Merge dataframes in new_data list

all_data = pd.concat(new_data, axis=0)

# %%
all_data.shape
# Out:
# (1059, 225)

# %%
all_data.head()
# Out:
#      Accounting Controversies  Adj_Close   Adj_High    Adj_Low   Adj_Open  \
# Year
# 2010                      NaN  31.715139  32.098239  31.113824  31.573704
# 2011                      NaN  45.682917  46.818213  44.536437  45.684722
# 2012                      NaN  28.770483  29.429041  28.099852  28.787997
# 2013                      NaN  48.211913  48.925603  47.418623  48.163829
# 2014                      NaN  44.993988  45.685349  44.272352  45.005556
#
#         Adj_Volume Agrochemical 5 % Revenue Agrochemical Products Alcohol  \
# Year
# 2010  2.614111e+05                      NaN                   NaN     NaN
# 2011  8.318734e+05                      NaN                   NaN     NaN
# 2012  1.021800e+06                      NaN                   NaN     NaN
# 2013  7.018853e+05                      NaN                   NaN     NaN
# 2014  9.142289e+05                      NaN                   NaN     NaN
#
#      Animal Testing Animal Testing Cosmetics Animal Testing Reduction  \
# Year
# 2010            NaN                      NaN                      NaN
# 2011            NaN                      NaN                      NaN
# 2012            NaN                      NaN                      NaN
# 2013            NaN                      NaN                      NaN
# 2014            NaN                      NaN                      NaN
#
#       Announced Layoffs To Total Employees  Anti Takeover Devices Above Two  \
# Year
# 2010                                   NaN                              NaN
# 2011                                   NaN                              NaN
# 2012                                   NaN                              NaN
# 2013                                   NaN                              NaN
# 2014                                   NaN                              NaN
#
#      Anti-Competition Controversies Count Anti-Personal Landmines  \
# Year
# 2010                                  NaN                     NaN
# 2011                                  NaN                     NaN
# 2012                                  NaN                     NaN
# 2013                                  NaN                     NaN
# 2014                                  NaN                     NaN
#
#      Anti-competition Controversies Armaments Audit Board Committee  \
# Year
# 2010                            NaN       NaN                   NaN
# 2011                            NaN       NaN                   NaN
# 2012                            NaN       NaN                   NaN
# 2013                            NaN       NaN                   NaN
# 2014                            NaN       NaN                   NaN
#
#      Audit Committee Expertise  Audit Committee Independence  \
# Year
# 2010                       NaN                           NaN
# 2011                       NaN                           NaN
# 2012                       NaN                           NaN
# 2013                       NaN                           NaN
# 2014                       NaN                           NaN
#
#      Audit Committee Mgt Independence  Audit Committee NonExecutive Members  \
# Year
# 2010                              NaN                                   NaN
# 2011                              NaN                                   NaN
# 2012                              NaN                                   NaN
# 2013                              NaN                                   NaN
# 2014                              NaN                                   NaN
#
#      Biodiversity Impact Reduction Board Attendance  \
# Year
# 2010                           NaN              NaN
# 2011                           NaN              NaN
# 2012                           NaN              NaN
# 2013                           NaN              NaN
# 2014                           NaN              NaN
#
#      Board Background and Skills Board Functions Policy  \
# Year
# 2010                         NaN                    NaN
# 2011                         NaN                    NaN
# 2012                         NaN                    NaN
# 2013                         NaN                    NaN
# 2014                         NaN                    NaN
#
#       Board Gender Diversity, Percent Board Individual Reelection  \
# Year
# 2010                              NaN                         NaN
# 2011                              NaN                         NaN
# 2012                              NaN                         NaN
# 2013                              NaN                         NaN
# 2014                              NaN                         NaN
#
#       Board Member Affiliations  Board Member Term Duration  Board Size  \
# Year
# 2010                        NaN                         NaN         NaN
# 2011                        NaN                         NaN         NaN
# 2012                        NaN                         NaN         NaN
# 2013                        NaN                         NaN         NaN
# 2014                        NaN                         NaN         NaN
#
#       Board Size More Ten Less Eight  Board Specific Skills, Percent  \
# Year
# 2010                             NaN                             NaN
# 2011                             NaN                             NaN
# 2012                             NaN                             NaN
# 2013                             NaN                             NaN
# 2014                             NaN                             NaN
#
#      Board Structure Policy Bribery, Corruption and Fraud Controversies  \
# Year
# 2010                    NaN                                         NaN
# 2011                    NaN                                         NaN
# 2012                    NaN                                         NaN
# 2013                    NaN                                         NaN
# 2014                    NaN                                         NaN
#
#      CEO Compensation Link to TSR CEO-Chairman Separation  CSR Strategy Score  \
# Year
# 2010                          NaN                     NaN                 NaN
# 2011                          NaN                     NaN                 NaN
# 2012                          NaN                     NaN                 NaN
# 2013                          NaN                     NaN                 NaN
# 2014                          NaN                     NaN                 NaN
#
#      CSR Sustainability Committee CSR Sustainability External Audit  \
# Year
# 2010                          NaN                               NaN
# 2011                          NaN                               NaN
# 2012                          NaN                               NaN
# 2013                          NaN                               NaN
# 2014                          NaN                               NaN
#
#      CSR Sustainability Reporting Chairman is ex-CEO  \
# Year
# 2010                          NaN                NaN
# 2011                          NaN                NaN
# 2012                          NaN                NaN
# 2013                          NaN                NaN
# 2014                          NaN                NaN
#
#      Climate Change Commercial Risks Opportunities      Close Cluster Bombs  \
# Year
# 2010                                           NaN  31.715139           NaN
# 2011                                           NaN  45.682917           NaN
# 2012                                           NaN  28.770483           NaN
# 2013                                           NaN  48.211913           NaN
# 2014                                           NaN  44.993988           NaN
#
#       Community Score Compensation Board Committee  \
# Year
# 2010              NaN                          NaN
# 2011              NaN                          NaN
# 2012              NaN                          NaN
# 2013              NaN                          NaN
# 2014              NaN                          NaN
#
#       Compensation Committee Independence  \
# Year
# 2010                                  NaN
# 2011                                  NaN
# 2012                                  NaN
# 2013                                  NaN
# 2014                                  NaN
#
#      Compensation Committee Mgt Independence  \
# Year
# 2010                                     NaN
# 2011                                     NaN
# 2012                                     NaN
# 2013                                     NaN
# 2014                                     NaN
#
#       Compensation Committee NonExecutive Members  \
# Year
# 2010                                          NaN
# 2011                                          NaN
# 2012                                          NaN
# 2013                                          NaN
# 2014                                          NaN
#
#      Compensation Improvement Tools Consumer Complaints Controversies  \
# Year
# 2010                            NaN                               NaN
# 2011                            NaN                               NaN
# 2012                            NaN                               NaN
# 2013                            NaN                               NaN
# 2014                            NaN                               NaN
#
#      Contraceptives Corporate Governance Board Committee  \
# Year
# 2010            NaN                                  NaN
# 2011            NaN                                  NaN
# 2012            NaN                                  NaN
# 2013            NaN                                  NaN
# 2014            NaN                                  NaN
#
#      Corporate Responsibility Awards Crisis Management Systems Date  \
# Year
# 2010                             NaN                       NaN  NaT
# 2011                             NaN                       NaN  NaT
# 2012                             NaN                       NaN  NaT
# 2013                             NaN                       NaN  NaT
# 2014                             NaN                       NaN  NaT
#
#      Day Care Services Director Election Majority Requirement  \
# Year
# 2010               NaN                                    NaN
# 2011               NaN                                    NaN
# 2012               NaN                                    NaN
# 2013               NaN                                    NaN
# 2014               NaN                                    NaN
#
#      Diseases of the Developing World  Dividend Dual Class Stock  \
# Year
# 2010                              NaN       0.0              NaN
# 2011                              NaN       0.0              NaN
# 2012                              NaN       0.0              NaN
# 2013                              NaN       0.0              NaN
# 2014                              NaN       0.0              NaN
#
#       ESG Controversies Score ESG Period Last Update Date  \
# Year
# 2010                      NaN                         NaN
# 2011                      NaN                         NaN
# 2012                      NaN                         NaN
# 2013                      NaN                         NaN
# 2014                      NaN                         NaN
#
#      Earnings Restatement Eco-Design Products Embryonic Stem Cell Research  \
# Year
# 2010                  NaN                 NaN                          NaN
# 2011                  NaN                 NaN                          NaN
# 2012                  NaN                 NaN                          NaN
# 2013                  NaN                 NaN                          NaN
# 2014                  NaN                 NaN                          NaN
#
#       Emissions Score Emissions Trading Employee Engagement Voluntary Work  \
# Year
# 2010              NaN               NaN                                NaN
# 2011              NaN               NaN                                NaN
# 2012              NaN               NaN                                NaN
# 2013              NaN               NaN                                NaN
# 2014              NaN               NaN                                NaN
#
#      Employees Health & Safety OHSAS 18001 Employees Health & Safety Team  \
# Year
# 2010                                   NaN                            NaN
# 2011                                   NaN                            NaN
# 2012                                   NaN                            NaN
# 2013                                   NaN                            NaN
# 2014                                   NaN                            NaN
#
#      Env Supply Chain Partnership Termination Environment Management Team  \
# Year
# 2010                                      NaN                         NaN
# 2011                                      NaN                         NaN
# 2012                                      NaN                         NaN
# 2013                                      NaN                         NaN
# 2014                                      NaN                         NaN
#
#      Environment Management Training  Environment Pillar Score  \
# Year
# 2010                             NaN                       NaN
# 2011                             NaN                       NaN
# 2012                             NaN                       NaN
# 2013                             NaN                       NaN
# 2014                             NaN                       NaN
#
#      Environmental Assets Under Mgt Environmental Controversies  \
# Year
# 2010                            NaN                         NaN
# 2011                            NaN                         NaN
# 2012                            NaN                         NaN
# 2013                            NaN                         NaN
# 2014                            NaN                         NaN
#
#      Environmental Expenditures Investments  \
# Year
# 2010                                    NaN
# 2011                                    NaN
# 2012                                    NaN
# 2013                                    NaN
# 2014                                    NaN
#
#      Environmental Investments Initiatives Environmental Materials Sourcing  \
# Year
# 2010                                   NaN                              NaN
# 2011                                   NaN                              NaN
# 2012                                   NaN                              NaN
# 2013                                   NaN                              NaN
# 2014                                   NaN                              NaN
#
#      Environmental Partnerships Environmental Products  \
# Year
# 2010                        NaN                    NaN
# 2011                        NaN                    NaN
# 2012                        NaN                    NaN
# 2013                        NaN                    NaN
# 2014                        NaN                    NaN
#
#      Environmental Project Financing Environmental Restoration Initiatives  \
# Year
# 2010                             NaN                                   NaN
# 2011                             NaN                                   NaN
# 2012                             NaN                                   NaN
# 2013                             NaN                                   NaN
# 2014                             NaN                                   NaN
#
#      Environmental Supply Chain Management Equal Voting Rights  \
# Year
# 2010                                   NaN                 NaN
# 2011                                   NaN                 NaN
# 2012                                   NaN                 NaN
# 2013                                   NaN                 NaN
# 2014                                   NaN                 NaN
#
#      Equator Principles Ethical Trading Initiative ETI  \
# Year
# 2010                NaN                            NaN
# 2011                NaN                            NaN
# 2012                NaN                            NaN
# 2013                NaN                            NaN
# 2014                NaN                            NaN
#
#      Executive Compensation Controversies  \
# Year
# 2010                                  NaN
# 2011                                  NaN
# 2012                                  NaN
# 2013                                  NaN
# 2014                                  NaN
#
#      Executive Compensation LT Objectives Executive Compensation Policy  \
# Year
# 2010                                  NaN                           NaN
# 2011                                  NaN                           NaN
# 2012                                  NaN                           NaN
# 2013                                  NaN                           NaN
# 2014                                  NaN                           NaN
#
#      Executive Individual Compensation  \
# Year
# 2010                               NaN
# 2011                               NaN
# 2012                               NaN
# 2013                               NaN
# 2014                               NaN
#
#       Executive Members Gender Diversity, Percent External Consultants  \
# Year
# 2010                                          NaN                  NaN
# 2011                                          NaN                  NaN
# 2012                                          NaN                  NaN
# 2013                                          NaN                  NaN
# 2014                                          NaN                  NaN
#
#      Extractive Industries Transparency Initiative Flexible Working Hours  \
# Year
# 2010                                           NaN                    NaN
# 2011                                           NaN                    NaN
# 2012                                           NaN                    NaN
# 2013                                           NaN                    NaN
# 2014                                           NaN                    NaN
#
#      Fundamental Human Rights ILO UN GMO Products GRI Report Guidelines  \
# Year
# 2010                             NaN          NaN                   NaN
# 2011                             NaN          NaN                   NaN
# 2012                             NaN          NaN                   NaN
# 2013                             NaN          NaN                   NaN
# 2014                             NaN          NaN                   NaN
#
#      Gambling Global Compact Signatory  Governance Pillar Score  \
# Year
# 2010      NaN                      NaN                      NaN
# 2011      NaN                      NaN                      NaN
# 2012      NaN                      NaN                      NaN
# 2013      NaN                      NaN                      NaN
# 2014      NaN                      NaN                      NaN
#
#      Green Buildings HIV-AIDS Program Health & Safety Policy  \
# Year
# 2010             NaN              NaN                    NaN
# 2011             NaN              NaN                    NaN
# 2012             NaN              NaN                    NaN
# 2013             NaN              NaN                    NaN
# 2014             NaN              NaN                    NaN
#
#      Health & Safety Training Healthy Food or Products       High  \
# Year
# 2010                      NaN                      NaN  32.098239
# 2011                      NaN                      NaN  46.818213
# 2012                      NaN                      NaN  29.429041
# 2013                      NaN                      NaN  48.925603
# 2014                      NaN                      NaN  45.685349
#
#      Human Rights Breaches Contractor Human Rights Contractor  \
# Year
# 2010                              NaN                     NaN
# 2011                              NaN                     NaN
# 2012                              NaN                     NaN
# 2013                              NaN                     NaN
# 2014                              NaN                     NaN
#
#      Human Rights Policy  Human Rights Score Hybrid Vehicles ISO 14000 or EMS  \
# Year
# 2010                 NaN                 NaN             NaN              NaN
# 2011                 NaN                 NaN             NaN              NaN
# 2012                 NaN                 NaN             NaN              NaN
# 2013                 NaN                 NaN             NaN              NaN
# 2014                 NaN                 NaN             NaN              NaN
#
#      ISO 9000 Improvement Tools Business Ethics  Independent Board Members  \
# Year
# 2010      NaN                               NaN                        NaN
# 2011      NaN                               NaN                        NaN
# 2012      NaN                               NaN                        NaN
# 2013      NaN                               NaN                        NaN
# 2014      NaN                               NaN                        NaN
#
#       Innovation Score Insider Dealings Controversies Instrument  \
# Year
# 2010               NaN                            NaN        NaN
# 2011               NaN                            NaN        NaN
# 2012               NaN                            NaN        NaN
# 2013               NaN                            NaN        NaN
# 2014               NaN                            NaN        NaN
#
#      Integrated Strategy in MD&A Internal Audit Department Reporting  \
# Year
# 2010                         NaN                                 NaN
# 2011                         NaN                                 NaN
# 2012                         NaN                                 NaN
# 2013                         NaN                                 NaN
# 2014                         NaN                                 NaN
#
#      Internal Promotion Labeled Wood Land Environmental Impact Reduction  \
# Year
# 2010                NaN          NaN                                 NaN
# 2011                NaN          NaN                                 NaN
# 2012                NaN          NaN                                 NaN
# 2013                NaN          NaN                                 NaN
# 2014                NaN          NaN                                 NaN
#
#             Low Management Departures  Management Score Management Training  \
# Year
# 2010  31.113824                   NaN               NaN                 NaN
# 2011  44.536437                   NaN               NaN                 NaN
# 2012  28.099852                   NaN               NaN                 NaN
# 2013  47.418623                   NaN               NaN                 NaN
# 2014  44.272352                   NaN               NaN                 NaN
#
#      Minimum Number of Shares to Vote NOx and SOx Emissions Reduction  \
# Year
# 2010                              NaN                             NaN
# 2011                              NaN                             NaN
# 2012                              NaN                             NaN
# 2013                              NaN                             NaN
# 2014                              NaN                             NaN
#
#      Noise Reduction Nomination Board Committee  \
# Year
# 2010             NaN                        NaN
# 2011             NaN                        NaN
# 2012             NaN                        NaN
# 2013             NaN                        NaN
# 2014             NaN                        NaN
#
#      Nomination Committee Mgt Independence  Non-Executive Board Members  \
# Year
# 2010                                   NaN                          NaN
# 2011                                   NaN                          NaN
# 2012                                   NaN                          NaN
# 2013                                   NaN                          NaN
# 2014                                   NaN                          NaN
#
#      Nuclear OECD Guidelines for Multinational Enterprises Obesity Risk  \
# Year
# 2010     NaN                                           NaN          NaN
# 2011     NaN                                           NaN          NaN
# 2012     NaN                                           NaN          NaN
# 2013     NaN                                           NaN          NaN
# 2014     NaN                                           NaN          NaN
#
#            Open Organic Products Initiatives  \
# Year
# 2010  31.573704                          NaN
# 2011  45.684722                          NaN
# 2012  28.787997                          NaN
# 2013  48.163829                          NaN
# 2014  45.005556                          NaN
#
#      Particulate Matter Emissions Reduction Period End Date  \
# Year
# 2010                                    NaN             NaT
# 2011                                    NaN             NaT
# 2012                                    NaN             NaT
# 2013                                    NaN             NaT
# 2014                                    NaN             NaT
#
#      Policy Board Diversity Policy Board Experience Policy Board Independence  \
# Year
# 2010                    NaN                     NaN                       NaN
# 2011                    NaN                     NaN                       NaN
# 2012                    NaN                     NaN                       NaN
# 2013                    NaN                     NaN                       NaN
# 2014                    NaN                     NaN                       NaN
#
#      Policy Board Size Policy Bribery and Corruption Policy Business Ethics  \
# Year
# 2010               NaN                           NaN                    NaN
# 2011               NaN                           NaN                    NaN
# 2012               NaN                           NaN                    NaN
# 2013               NaN                           NaN                    NaN
# 2014               NaN                           NaN                    NaN
#
#      Policy Career Development Policy Child Labor  \
# Year
# 2010                       NaN                NaN
# 2011                       NaN                NaN
# 2012                       NaN                NaN
# 2013                       NaN                NaN
# 2014                       NaN                NaN
#
#      Policy Community Involvement Policy Customer Health & Safety  \
# Year
# 2010                          NaN                             NaN
# 2011                          NaN                             NaN
# 2012                          NaN                             NaN
# 2013                          NaN                             NaN
# 2014                          NaN                             NaN
#
#      Policy Data Privacy Policy Diversity and Opportunity Policy Emissions  \
# Year
# 2010                 NaN                              NaN              NaN
# 2011                 NaN                              NaN              NaN
# 2012                 NaN                              NaN              NaN
# 2013                 NaN                              NaN              NaN
# 2014                 NaN                              NaN              NaN
#
#      Policy Employee Health & Safety Policy Energy Efficiency  \
# Year
# 2010                             NaN                      NaN
# 2011                             NaN                      NaN
# 2012                             NaN                      NaN
# 2013                             NaN                      NaN
# 2014                             NaN                      NaN
#
#      Policy Environmental Supply Chain Policy Equal Voting Right  \
# Year
# 2010                               NaN                       NaN
# 2011                               NaN                       NaN
# 2012                               NaN                       NaN
# 2013                               NaN                       NaN
# 2014                               NaN                       NaN
#
#      Policy Executive Compensation ESG Performance  \
# Year
# 2010                                           NaN
# 2011                                           NaN
# 2012                                           NaN
# 2013                                           NaN
# 2014                                           NaN
#
#      Policy Executive Compensation Performance Policy Executive Retention  \
# Year
# 2010                                       NaN                        NaN
# 2011                                       NaN                        NaN
# 2012                                       NaN                        NaN
# 2013                                       NaN                        NaN
# 2014                                       NaN                        NaN
#
#      Policy Fair Competition Policy Fair Trade Policy Forced Labor  \
# Year
# 2010                     NaN               NaN                 NaN
# 2011                     NaN               NaN                 NaN
# 2012                     NaN               NaN                 NaN
# 2013                     NaN               NaN                 NaN
# 2014                     NaN               NaN                 NaN
#
#      Policy Freedom of Association Policy Human Rights  \
# Year
# 2010                           NaN                 NaN
# 2011                           NaN                 NaN
# 2012                           NaN                 NaN
# 2013                           NaN                 NaN
# 2014                           NaN                 NaN
#
#      Policy Responsible Marketing Policy Shareholder Engagement  \
# Year
# 2010                          NaN                           NaN
# 2011                          NaN                           NaN
# 2012                          NaN                           NaN
# 2013                          NaN                           NaN
# 2014                          NaN                           NaN
#
#      Policy Skills Training Policy Supply Chain Health & Safety  \
# Year
# 2010                    NaN                                 NaN
# 2011                    NaN                                 NaN
# 2012                    NaN                                 NaN
# 2013                    NaN                                 NaN
# 2014                    NaN                                 NaN
#
#      Policy Sustainable Packaging Policy Water Efficiency Pornography  \
# Year
# 2010                          NaN                     NaN         NaN
# 2011                          NaN                     NaN         NaN
# 2012                          NaN                     NaN         NaN
# 2013                          NaN                     NaN         NaN
# 2014                          NaN                     NaN         NaN
#
#      Product Access Low Price Product Environmental Responsible Use  \
# Year
# 2010                      NaN                                   NaN
# 2011                      NaN                                   NaN
# 2012                      NaN                                   NaN
# 2013                      NaN                                   NaN
# 2014                      NaN                                   NaN
#
#      Product Impact Minimization Product Quality Controversies Product Recall  \
# Year
# 2010                         NaN                           NaN            NaN
# 2011                         NaN                           NaN            NaN
# 2012                         NaN                           NaN            NaN
# 2013                         NaN                           NaN            NaN
# 2014                         NaN                           NaN            NaN
#
#      Product Responsibility Monitoring  Product Responsibility Score  \
# Year
# 2010                               NaN                           NaN
# 2011                               NaN                           NaN
# 2012                               NaN                           NaN
# 2013                               NaN                           NaN
# 2014                               NaN                           NaN
#
#      Product Sales at Discount to Emerging Markets Profit Warnings  \
# Year
# 2010                                           NaN             NaN
# 2011                                           NaN             NaN
# 2012                                           NaN             NaN
# 2013                                           NaN             NaN
# 2014                                           NaN             NaN
#
#      Public Availability Corporate Statutes Quality Mgt Systems  \
# Year
# 2010                                    NaN                 NaN
# 2011                                    NaN                 NaN
# 2012                                    NaN                 NaN
# 2013                                    NaN                 NaN
# 2014                                    NaN                 NaN
#
#      Renewable Energy Use Renewable/Clean Energy Products  \
# Year
# 2010                  NaN                             NaN
# 2011                  NaN                             NaN
# 2012                  NaN                             NaN
# 2013                  NaN                             NaN
# 2014                  NaN                             NaN
#
#      Resource Reduction Policy Resource Reduction Targets  Resource Use Score  \
# Year
# 2010                       NaN                        NaN                 NaN
# 2011                       NaN                        NaN                 NaN
# 2012                       NaN                        NaN                 NaN
# 2013                       NaN                        NaN                 NaN
# 2014                       NaN                        NaN                 NaN
#
#      Retailing Responsibility Shareholder Rights Policy  \
# Year
# 2010                      NaN                       NaN
# 2011                      NaN                       NaN
# 2012                      NaN                       NaN
# 2013                      NaN                       NaN
# 2014                      NaN                       NaN
#
#      Shareholders Approval Stock Compensation Plan  Shareholders Score  \
# Year
# 2010                                           NaN                 NaN
# 2011                                           NaN                 NaN
# 2012                                           NaN                 NaN
# 2013                                           NaN                 NaN
# 2014                                           NaN                 NaN
#
#      Shareholders Vote on Executive Pay Six Sigma and Quality Mgt Systems  \
# Year
# 2010                                NaN                               NaN
# 2011                                NaN                               NaN
# 2012                                NaN                               NaN
# 2013                                NaN                               NaN
# 2014                                NaN                               NaN
#
#       Social Pillar Score  Split Staff Transportation Impact Reduction  \
# Year
# 2010                  NaN    1.0                                   NaN
# 2011                  NaN    1.0                                   NaN
# 2012                  NaN    1.0                                   NaN
# 2013                  NaN    1.0                                   NaN
# 2014                  NaN    1.0                                   NaN
#
#      Stakeholder Engagement Strikes Succession Plan Supplier ESG training  \
# Year
# 2010                    NaN     NaN             NaN                   NaN
# 2011                    NaN     NaN             NaN                   NaN
# 2012                    NaN     NaN             NaN                   NaN
# 2013                    NaN     NaN             NaN                   NaN
# 2014                    NaN     NaN             NaN                   NaN
#
#      Supply Chain Health & Safety Training  \
# Year
# 2010                                   NaN
# 2011                                   NaN
# 2012                                   NaN
# 2013                                   NaN
# 2014                                   NaN
#
#      Sustainability Compensation Incentives Sustainable Building Products  \
# Year
# 2010                                    NaN                           NaN
# 2011                                    NaN                           NaN
# 2012                                    NaN                           NaN
# 2013                                    NaN                           NaN
# 2014                                    NaN                           NaN
#
#       TRESG Combined Score  TRESG Score Take-back and Recycling Initiatives  \
# Year
# 2010                   NaN          NaN                                 NaN
# 2011                   NaN          NaN                                 NaN
# 2012                   NaN          NaN                                 NaN
# 2013                   NaN          NaN                                 NaN
# 2014                   NaN          NaN                                 NaN
#
#      Tobacco Toxic Chemicals Reduction Training and Development Policy  \
# Year
# 2010     NaN                       NaN                             NaN
# 2011     NaN                       NaN                             NaN
# 2012     NaN                       NaN                             NaN
# 2013     NaN                       NaN                             NaN
# 2014     NaN                       NaN                             NaN
#
#      VOC Emissions Reduction Veto Power or Golden share        Volume  \
# Year
# 2010                     NaN                        NaN  2.614111e+05
# 2011                     NaN                        NaN  8.318734e+05
# 2012                     NaN                        NaN  1.021800e+06
# 2013                     NaN                        NaN  7.018853e+05
# 2014                     NaN                        NaN  9.142289e+05
#
#      Voting Cap  Voting Cap Percentage Wages Working Condition Controversies  \
# Year
# 2010        NaN                    NaN                                   NaN
# 2011        NaN                    NaN                                   NaN
# 2012        NaN                    NaN                                   NaN
# 2013        NaN                    NaN                                   NaN
# 2014        NaN                    NaN                                   NaN
#
#      Waste Reduction Initiatives Water Technologies Whistleblower Protection  \
# Year
# 2010                         NaN                NaN                      NaN
# 2011                         NaN                NaN                      NaN
# 2012                         NaN                NaN                      NaN
# 2013                         NaN                NaN                      NaN
# 2014                         NaN                NaN                      NaN
#
#       Workforce Score e-Waste Reduction
# Year
# 2010              NaN               NaN
# 2011              NaN               NaN
# 2012              NaN               NaN
# 2013              NaN               NaN
# 2014              NaN               NaN

# %%
all_data.to_csv('aggr_data.csv', sep = ',')
